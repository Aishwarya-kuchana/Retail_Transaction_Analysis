# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\lenovo\Desktop\EDA project dataset\Retail_Dataset.csv")
df
# Out:
#        CustomerID ProductID  Quantity      Price      TransactionDate  \
# 0          109318         C         7  80.079844  2023-12-26 12:32:00
# 1          993229         C         4  75.195229  2023-08-05 00:00:00
# 2          579675         A         8  31.528816  2024-03-11 18:51:00
# 3          799826         D         5  98.880218  2023-10-27 22:00:00
# 4          121413         A         7  93.188512  2023-12-22 11:38:00
# ...           ...       ...       ...        ...                  ...
# 99995      726461         A         2  56.078258  2023-07-17 16:59:00
# 99996      328056         A         6  88.516406  2023-05-30 09:04:00
# 99997      887304         B         4  72.385564  2023-08-25 07:59:00
# 99998      326401         C         5  66.542239  2024-02-05 19:45:00
# 99999      771566         C         5  38.087766  2024-02-04 11:53:00
#
#       PaymentMethod                                      StoreLocation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CustomerID          100000 non-null  int64
#  1   ProductID           100000 non-null  object
#  2   Quantity            100000 non-null  int64
#  3   Price               100000 non-null  float64
#  4   TransactionDate     100000 non-null  object
#  5   PaymentMethod       100000 non-null  object
#  6   StoreLocation       100000 non-null  object
#  7   ProductCategory     100000 non-null  object
#  8   DiscountApplied(%)  100000 non-null  float64
#  9   TotalAmount         100000 non-null  float64
#  10  Date                100000 non-null  object
#  11  Time                100000 non-null  object
#  12  Month               100000 non-null  object
#  13  Year                100000 non-null  int64
#  14  DayOfWeek           100000 non-null  object
# ...

# %%
df.describe()
# Out:
#           CustomerID       Quantity          Price  DiscountApplied(%)  \
# count  100000.000000  100000.000000  100000.000000       100000.000000
# mean   500463.982180       5.009290      55.067344           10.020155
# std    288460.917524       2.579808      25.971567            5.779534
# min        14.000000       1.000000      10.000430            0.000046
# 25%    250693.750000       3.000000      32.549474            5.001013
# 50%    499679.000000       5.000000      55.116789           10.030353
# 75%    751104.750000       7.000000      77.456763           15.018367
# max    999997.000000       9.000000      99.999284           19.999585
#
#          TotalAmount           Year
# count  100000.000000  100000.000000
# mean      248.334955    2023.327330
# std       184.554792       0.469241
# min         8.274825    2023.000000
# 25%        95.163418    2023.000000
# 50%       200.368393    2023.000000
# 75%       362.009980    2024.000000
# ...

# %%
plt.figure(figsize=(5,2))
sns.boxplot(df["TotalAmount"])
plt.title('TotalAmount Boxplot')
plt.show()

# %%
sns.histplot(df["TotalAmount"], kde=True, bins=50)
plt.title('TotalAmount Distribution')
plt.show()

# %%
sns.histplot(df["DiscountApplied(%)"], kde=True, bins=50)
plt.title('DiscountApplied(%) Distribution')
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x="ProductCategory", order=df["ProductCategory"].value_counts().index)
plt.title('Productcategory Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x="PaymentMethod", order=df["PaymentMethod"].value_counts().index)
plt.title('PaymentMethod Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x="State", order=df["State"].value_counts().index)
plt.title('State Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
df.groupby(["PaymentMethod","ProductCategory"]).size()
# Out:
# PaymentMethod  ProductCategory
# Cash           Books              6243
#                Clothing           6278
#                Electronics        6282
#                Home Decor         6205
# Credit Card    Books              6256
#                Clothing           6345
#                Electronics        6295
#                Home Decor         6138
# Debit Card     Books              6191
#                Clothing           6148
#                Electronics        6240
#                Home Decor         6312
# PayPal         Books              6341
#                Clothing           6285
#                Electronics        6173
#                Home Decor         6268
# dtype: int64

# %%
df.groupby("ProductCategory")["DiscountApplied(%)"].mean()
# Out:
# ProductCategory
# Books           9.996935
# Clothing       10.019378
# Electronics     9.981941
# Home Decor     10.082572
# Name: DiscountApplied(%), dtype: float64

# %%
df[["Quantity","TotalAmount"]].corr()
# Out:
#              Quantity  TotalAmount
# Quantity     1.000000     0.691847
# TotalAmount  0.691847     1.000000

# %%
df[["Price","Quantity","TotalAmount"]].corr()
# Out:
#                 Price  Quantity  TotalAmount
# Price        1.000000  0.001787     0.636294
# Quantity     0.001787  1.000000     0.691847
# TotalAmount  0.636294  0.691847     1.000000

# %%
df.groupby("ProductCategory")["TotalAmount"].mean()
# Out:
# ProductCategory
# Books          250.003477
# Clothing       247.665324
# Electronics    247.968578
# Home Decor     247.699770
# Name: TotalAmount, dtype: float64

# %%
df.groupby("PaymentMethod")["TotalAmount"].mean()
# Out:
# PaymentMethod
# Cash           248.208811
# Credit Card    247.804501
# Debit Card     249.206494
# PayPal         248.125138
# Name: TotalAmount, dtype: float64

# %%
sns.barplot(x='PaymentMethod', y='TotalAmount', data=df, estimator='mean', errorbar=None)
plt.title('Total Revenue by Payment Method')
plt.show()

# %%
df.groupby("State")["TotalAmount"].mean()
# Out:
# State
# AA    254.295162
# AE    244.182229
# AK    244.576651
# AL    239.154287
# AP    249.489353
#          ...
# VT    242.288701
# WA    253.421898
# WI    247.681903
# WV    247.731369
# WY    251.378626
# Name: TotalAmount, Length: 62, dtype: float64

# %%
df.groupby("Month")["TotalAmount"].mean()
# Out:
# Month
# April        244.816351
# August       248.217539
# December     250.873488
# February     244.323194
# January      249.133241
# July         248.057522
# June         250.681163
# March        249.290297
# May          250.307117
# November     247.201410
# October      246.180264
# September    250.621513
# Name: TotalAmount, dtype: float64

# %%
sns.lineplot(x='Month', y='TotalAmount', data=df, estimator='mean', errorbar=None, sort=False)
plt.title('Monthly Revenue Trend')
plt.show()

# %%
df.groupby("DayOfWeek")["TotalAmount"].mean()
# Out:
# DayOfWeek
# Friday       248.943445
# Monday       245.000562
# Saturday     249.498530
# Sunday       247.382937
# Thursday     251.320850
# Tuesday      248.370953
# Wednesday    247.805488
# Name: TotalAmount, dtype: float64

# %%
df.groupby("Time")["TotalAmount"].mean()
# Out:
# Time
# 00:00:00    234.419407
# 00:01:00    271.584158
# 00:02:00    228.953556
# 00:03:00    218.103406
# 00:04:00    241.567689
#                ...
# 23:55:00    238.390413
# 23:56:00    247.794689
# 23:57:00    243.754528
# 23:58:00    220.059716
# 23:59:00    268.947721
# Name: TotalAmount, Length: 1440, dtype: float64

# %%
df.groupby(["Month","Time","DayOfWeek","State","City"])["TotalAmount"].mean()
# Out:
# Month      Time      DayOfWeek  State  City
# April      00:00:00  Saturday   IN     South Robertfurt    191.647347
#                      Sunday     IN     Ferrellborough       56.563934
#                      Thursday   GU     Potterside           86.640986
#                                 KS     Sarahview           652.830454
#                      Tuesday    NH     Johnsonborough      231.054816
#                                                               ...
# September  23:59:00  Thursday   AA     APO AA 88272        126.008345
#                                 GU     North Cherylside     74.421842
#                                 PA     Lake Melvin         377.059066
#                      Tuesday    AR     Rodgerstown         194.586954
#                                 WI     Maysview            162.946429
# Name: TotalAmount, Length: 100000, dtype: float64

# %%
df.groupby(["State","ProductCategory"])["TotalAmount"].mean()
# Out:
# State  ProductCategory
# AA     Books              265.965526
#        Clothing           256.639118
#        Electronics        245.363956
#        Home Decor         249.274130
# AE     Books              240.767026
#                              ...
# WV     Home Decor         258.138931
# WY     Books              248.009551
#        Clothing           250.112164
#        Electronics        261.523967
#        Home Decor         245.462537
# Name: TotalAmount, Length: 248, dtype: float64
